# %% [markdown]
# # Amount Freight Country Shipped
# Goals: Show data of the average freight in ship country

# %%
#import library

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data
data=pd.read_csv('ship country average freight.csv')
data
# Out:
#     ShipCountry  AverageFreight
# 0       Ireland        200.2100
# 1       Austria        186.4596
# 2           USA        117.9704
# 3       Germany        105.8452
# 4        Sweden        100.1169
# 5        Canada         85.6783
# 6       Denmark         85.6284
# 7   Switzerland         74.3800
# 8       Belgium         70.8721
# 9        France         58.0544
# 10           UK         57.7919
# 11     Portugal         57.3240
# 12    Venezuela         54.5746
# 13       Brazil         52.1836
# 14       Norway         42.1250
# 15    Argentina         39.4392
# 16        Spain         39.0075
# 17      Finland         32.9200
# 18        Italy         31.1710
# 19       Mexico         30.6666
# 20       Poland         28.6333

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x =	'ShipCountry', y ='AverageFreight',data=data,ax=ax)
